# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import datasets

mnist = datasets.load_digits()
x = mnist.data
y = mnist.target

print(x.shape)
# Out:
# (1797, 64)

# %% [markdown]
# **1. PCA**

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA()
x_pca = pca.fit_transform(x)
cum_ratio = np.cumsum(pca.explained_variance_ratio_)

f, ax = plt.subplots(figsize=(8,6))
plt.plot(range(len(cum_ratio)), cum_ratio)
plt.ylabel('Explained Variance')
plt.xlabel('Components')
# Out:
# Text(0.5, 0, 'Components')

# %% [markdown]
# A. I'm choosing to use 20 components because that is the elbow of the graph and therfore variance will decrease after this point.

# %%
pca = PCA(n_components = 20)
data_pca = pca.fit_transform(x)

f, ax = plt.subplots(figsize = (9,7))
plt.scatter(data_pca[:, 0], data_pca[:, 1],
            c=y, edgecolor='none', alpha=0.5)
plt.xlabel('component 1')
plt.ylabel('component 2')
plt.title('First 2 Principle Components')
# Out:
# Text(0.5, 1.0, 'First 2 Principle Components')

# %% [markdown]
# B. The purple looks to be pretty condensed at the top and bottom of the plot. The other colors are more scattered.

# %% [markdown]
# C. PCA is used to reduce dimensionality in the data. It accomplishes this by dropping the the axes with the lowest variance. I guess the drawback would be that it isn't necessary. For models like KNN it would be helpful since dimensionality can ruin a KNN model. But in general most models and algrithms don't need reduced dimensionality.

# %% [markdown]
# **2. TSNE**

# %%
from sklearn.manifold import TSNE

pca = PCA(n_components=50)
x_pca = pca.fit_transform(x)

rows = np.arange(1797)
np.random.shuffle(rows)
n_select = 10000

tsne = TSNE(n_components=2, verbose=1, perplexity=50, n_iter=1000, learning_rate=200)
tsne_results = tsne.fit_transform(x_pca[rows[:n_select],:])
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 1797 samples in 0.002s...
# [t-SNE] Computed neighbors for 1797 samples in 0.274s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1797
# [t-SNE] Computed conditional probabilities for sample 1797 / 1797
# [t-SNE] Mean sigma: 8.639315
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 61.579720
# [t-SNE] KL divergence after 1000 iterations: 0.683781

# %%
df_tsne = pd.DataFrame(tsne_results, columns=['component 1', 'component 2'])
df_tsne['label'] = y[rows[:n_select]]
sns.lmplot(x='component 1', y='component 2', data=df_tsne, hue='label', palette = 'RdBu', fit_reg=False)

# %% [markdown]
# A. This plot is way tighter than the PCA used above. Each cluster is prtty much on it's own.

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=10, n_iter=1000, learning_rate=200)
tsne_results = tsne.fit_transform(x_pca[rows[:n_select],:])

df_tsne = pd.DataFrame(tsne_results, columns=['component 1', 'component 2'])
df_tsne['label'] = y[rows[:n_select]]

sns.lmplot(x='component 1', y='component 2', data=df_tsne, hue='label', palette = 'RdBu', fit_reg=False)
# Out:
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 1797 samples in 0.003s...
# [t-SNE] Computed neighbors for 1797 samples in 0.218s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1797
# [t-SNE] Computed conditional probabilities for sample 1797 / 1797
# [t-SNE] Mean sigma: 6.719964
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 67.852570
# [t-SNE] KL divergence after 1000 iterations: 0.884606

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=5, n_iter=1000, learning_rate=200)
tsne_results = tsne.fit_transform(x_pca[rows[:n_select],:])

df_tsne = pd.DataFrame(tsne_results, columns=['component 1', 'component 2'])
df_tsne['label'] = y[rows[:n_select]]

sns.lmplot(x='component 1', y='component 2', data=df_tsne, hue='label', palette = 'RdBu', fit_reg=False)
# Out:
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 1797 samples in 0.002s...
# [t-SNE] Computed neighbors for 1797 samples in 0.237s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1797
# [t-SNE] Computed conditional probabilities for sample 1797 / 1797
# [t-SNE] Mean sigma: 5.706742
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 73.510170
# [t-SNE] KL divergence after 1000 iterations: 0.925015

# %% [markdown]
# B. Reducing perplexity makes the clusters seperate and become less tight.

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=5, n_iter=300, learning_rate=200)
tsne_results = tsne.fit_transform(x_pca[rows[:n_select],:])

df_tsne = pd.DataFrame(tsne_results, columns=['component 1', 'component 2'])
df_tsne['label'] = y[rows[:n_select]]

sns.lmplot(x='component 1', y='component 2', data=df_tsne, hue='label', palette = 'RdBu', fit_reg=False)
# Out:
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 1797 samples in 0.003s...
# [t-SNE] Computed neighbors for 1797 samples in 0.224s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1797
# [t-SNE] Computed conditional probabilities for sample 1797 / 1797
# [t-SNE] Mean sigma: 5.706742
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 73.035301
# [t-SNE] KL divergence after 300 iterations: 1.797904

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=5, n_iter=1000, learning_rate=10)
tsne_results = tsne.fit_transform(x_pca[rows[:n_select],:])

df_tsne = pd.DataFrame(tsne_results, columns=['component 1', 'component 2'])
df_tsne['label'] = y[rows[:n_select]]

sns.lmplot(x='component 1', y='component 2', data=df_tsne, hue='label', palette = 'RdBu', fit_reg=False)
# Out:
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 1797 samples in 0.002s...
# [t-SNE] Computed neighbors for 1797 samples in 0.189s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1797
# [t-SNE] Computed conditional probabilities for sample 1797 / 1797
# [t-SNE] Mean sigma: 5.706742
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 73.032043
# [t-SNE] KL divergence after 1000 iterations: 1.067346

# %% [markdown]
# C. There were minimal changes with variation in the learning rate. Looks like the model is pretty robust in that sense.

# %% [markdown]
# **3. K-Means Clustering**

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
kmeans = KMeans(n_clusters=10, n_init=50)
kmeans.fit(x)
labels = kmeans.labels_
silhouette_score(x, labels, metric='euclidean')
# Out:
# 0.18246601958265693

# %% [markdown]
# A. After doing some research using Google, it looks like 10 is the ideal value for k.

# %% [markdown]
# B. Used the Silhouette Score to evaluate my model. This coefficient is the mean distance between a sample and all other points in the next nearest cluste subtracted by the mean distance between a sample and all other points in the same class.

# %% [markdown]
# C. Below

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=30, n_iter=1000, learning_rate=50)
tsne_results = tsne.fit_transform(x[rows[:n_select],:])

df_tsne = pd.DataFrame(tsne_results, columns=['component 1', 'component 2'])
df_tsne['label'] = labels[rows[:n_select]]

sns.lmplot(x='component 1', y='component 2', data=df_tsne, hue='label', palette = 'RdBu', fit_reg=False)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 1797 samples in 0.004s...
# [t-SNE] Computed neighbors for 1797 samples in 0.357s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1797
# [t-SNE] Computed conditional probabilities for sample 1797 / 1797
# [t-SNE] Mean sigma: 8.121138
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 62.242065
# [t-SNE] KL divergence after 1000 iterations: 0.763415

# %% [markdown]
# D. I did not scale my data.

# %% [markdown]
# E. Overall it looks pretty robust, it is in distinct little groups but the colors are more mixed than the previous models.

# %% [markdown]
# **4. Hierarchical Clustering**

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
x_cluster = x[:100]

# %% [markdown]
# A.

# %%
Z = linkage(x_cluster, 'complete')
plt.figure(figsize=(15, 12))
_ = dendrogram(Z)

# %% [markdown]
# B. Looks like there are about 10 clusters when using .5 on the y-axis.

# %%
Z = linkage(x_cluster, 'average')
plt.figure(figsize=(15, 12))
_ = dendrogram(Z)

# %% [markdown]
# C. Comapred has more clusters than average linkage. Complete makes connections earlier than average did.
